# %%
import pandas as pd
pd.set_option('display.max_columns', None)

df = pd.read_csv('../data/FC26_20250921.csv', low_memory=False)
df.shape
# Out:
# (18405, 110)

# %%
df.columns.tolist()
# Out:
# ['player_id',
#  'player_url',
#  'fifa_version',
#  'fifa_update',
#  'fifa_update_date',
#  'short_name',
#  'long_name',
#  'player_positions',
#  'overall',
#  'potential',
#  'value_eur',
#  'wage_eur',
#  'age',
#  'dob',
#  'height_cm',
#  'weight_kg',
#  'league_id',
#  'league_name',
#  'league_level',
#  'club_team_id',
#  'club_name',
#  'club_position',
#  'club_jersey_number',
#  'club_loaned_from',
#  'club_joined_date',
#  'club_contract_valid_until_year',
#  'nationality_id',
#  'nationality_name',
#  'nation_team_id',
#  'nation_position',
#  'nation_jersey_number',
#  'preferred_foot',
#  'weak_foot',
#  'skill_moves',
#  'international_reputation',
#  'work_rate',
#  'body_type',
#  'real_face',
#  'release_clause_eur',
#  'player_tags',
#  'player_traits',
#  'pace',
#  'shooting',
#  'passing',
#  'dribbling',
#  'defending',
#  'physic',
#  'attacking_crossing',
#  'attacking_finishing',
#  'attacking_heading_accuracy',
#  'attacking_short_passing',
# ...

# %%
key_cols = ['short_name','age','player_positions','club_name','league_name','value_eur',
            'wage_eur','club_contract_valid_until_year','preferred_foot',
            'pace','shooting','passing','dribbling','defending','physic']
df[key_cols].isnull().sum()
# Out:
# short_name                           0
# age                                  0
# player_positions                     0
# club_name                           89
# league_name                         89
# value_eur                            0
# wage_eur                             0
# club_contract_valid_until_year      89
# preferred_foot                       0
# pace                              2062
# shooting                          2062
# passing                           2062
# dribbling                         2062
# defending                         2062
# physic                            2062
# dtype: int64

# %%
df[df['pace'].isnull()]['player_positions'].value_counts()
# Out:
# player_positions
# GK    2062
# Name: count, dtype: int64

# %%
df[['short_name','age','player_positions','club_name','league_name','value_eur','preferred_foot']].head(10)
# Out:
#         short_name  age player_positions            club_name     league_name  \
# 0    J. Bellingham   22          CAM, CM          Real Madrid         La Liga
# 1      F. Valverde   26      CM, CDM, RB          Real Madrid         La Liga
# 2       J. Kimmich   30      CDM, RB, CM    FC Bayern München      Bundesliga
# 3        A. Hakimi   26           RB, RM  Paris Saint-Germain         Ligue 1
# 4       N. Barella   28               CM                Inter         Serie A
# 5    H. Çalhanoğlu   31          CDM, CM                Inter         Serie A
# 6       F. Dimarco   27           LB, LM                Inter         Serie A
# 7  A. Mac Allister   26          CM, CDM            Liverpool  Premier League
# 8            Rodri   29          CDM, CM      Manchester City  Premier League
# 9     A. Griezmann   34      ST, LM, CAM      Atlético Madrid         La Liga
#
#    value_eur preferred_foot
# 0  174500000          Right
# 1  120500000          Right
# ...

# %%
df['player_positions'].value_counts().head(15)
# Out:
# player_positions
# CB             2429
# GK             2062
# ST             1581
# CDM, CM         978
# LB, LM          898
# RB, RM          766
# CM, CDM         693
# CM              422
# CAM, CM         417
# CM, CAM         290
# CDM, CM, CB     216
# ST, CAM         215
# RM, RW          209
# LM, RM, LW      207
# CB, RB          206
# Name: count, dtype: int64
